# %% [markdown]
# ## My Metric of choice:
# ## Air Quality
#
# Obviously, good air quality is ***very important*** for walking your fish, because you don't want his bowl to get covered in soot, and you want your lungs to survive the trip!

# %% [markdown]
# #### Firstly, I imported the dataset as well as the necessary libraries:

# %%
import pandas as pd ## Importing pandas
import matplotlib.pyplot as plt
airQuality = pd.read_csv("https://data.wprdc.org/datastore/dump/4ab1e23f-3262-4bd3-adbf-f72f0119108b") ## Initial reading of the dataset

# %% [markdown]
# #### Secondly, I printed out the first 15 entries in the dataset to observe the layout:

# %%
airQuality.head(15)
# Out:
#     _id        date               site parameter  index_value description  \
# 0     1  2016-01-01      Lawrenceville     PM25B           25        Good
# 1     2  2016-01-01         Flag Plaza        CO            0        Good
# 2     3  2016-01-01  Harrison Township     OZONE           31        Good
# 3     4  2016-01-01             Avalon       SO2           10        Good
# 4     5  2016-01-01            Lincoln      PM25           35        Good
# 5     6  2016-01-01            Lincoln      PM10           11        Good
# 6     7  2016-01-01      South Fayette       SO2            3        Good
# 7     8  2016-01-01     North Braddock     PM10B           12        Good
# 8     9  2016-01-01       Parkway East        CO            4        Good
# 9    10  2016-01-01         Flag Plaza      PM10            7        Good
# 10   11  2016-01-01          Liberty 2   PM25(2)           28        Good
# 11   12  2016-01-01    Lawrenceville 2       SO2            1        Good
# ...

# %% [markdown]
# #### Thirdly, I visualized the dataset to get an initial picture of where neighborhoods stand

# %%
plt.figure(figsize=(12, 6))
plt.bar(airQuality['site'], airQuality['index_value'], color='skyblue')
plt.xlabel('Neighborhood')
plt.ylabel('Air Quality Value')
plt.title('Air Quality in Different Neighborhoods')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
# Show the plot
plt.show()

# %% [markdown]
# #### Fourthly, I created a query mask to eliminate any neighborhoods that had moderate or bad air quality and printed the dataset

# %%
air_query_mask = airQuality['description'].str.contains("Good") ## Eliminating any neighborhoods with moderate or bad air quality
good_air = airQuality[air_query_mask] ## making a separate dataframe for neighborhoods with good air
good_air.head(20)
# Out:
#     _id        date                   site parameter  index_value description  \
# 0     1  2016-01-01          Lawrenceville     PM25B           25        Good
# 1     2  2016-01-01             Flag Plaza        CO            0        Good
# 2     3  2016-01-01      Harrison Township     OZONE           31        Good
# 3     4  2016-01-01                 Avalon       SO2           10        Good
# 4     5  2016-01-01                Lincoln      PM25           35        Good
# 5     6  2016-01-01                Lincoln      PM10           11        Good
# 6     7  2016-01-01          South Fayette       SO2            3        Good
# 7     8  2016-01-01         North Braddock     PM10B           12        Good
# 8     9  2016-01-01           Parkway East        CO            4        Good
# 9    10  2016-01-01             Flag Plaza      PM10            7        Good
# 10   11  2016-01-01              Liberty 2   PM25(2)           28        Good
# ...

# %% [markdown]
# #### Lastly, I visualized the dataset of neighborhoods with good air

# %%
plt.figure(figsize=(12, 6))
plt.bar(good_air['site'], good_air['index_value'], color='skyblue')
plt.xlabel('Neighborhood')
plt.ylabel('Air Quality Value')
plt.title('Air Quality in Different Neighborhoods')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
# Show the plot
plt.show()

# %% [markdown]
# ## Takeaway
# While an Initial look at the graph would seem to indicate that Lawrenceville has the best air quality, the dataset reported some inconsistencies with how Lawrenceville 2 records air quality in comparison to the rest of the sites. As such, I believe that West Mifflin is the neighborhood with the best air quality.
